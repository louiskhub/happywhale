# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import numpy as np

# %%
x = tf.io.read_file("../OurSpeciesTrainingData/10009936a338f9.jpg")
x = tf.image.decode_jpeg(x, channels=1)
x = tf.cast(x, dtype=tf.float32)
x *= (2 / 255)
x -= 1

# %%
ds = tf.data.Dataset.from_tensor_slices([x])

# %%
def do(x):
    print(type(x),"ja")
    return x
    x = tf.keras.preprocessing.image.random_brightness(x, (0.4,0.8))
    return tf.convert_to_tensor(x)

# %%
i = tf.image.random_crop(x,[220,220,1])
plt.imshow(tf.image.resize(i,(256,256)))

# %%
plt.imshow(tf.image.random_contrast(x, 0.2, 0.5))

# %%
for i in ds.take(1):
    print(i)
# Out:
# tf.Tensor(
# [[[-0.51372546]
#   [-0.5607843 ]
#   [-0.5686274 ]
#   ...
#   [-0.41960782]
#   [-0.38823527]
#   [-0.36470586]]
#
#  [[-0.4980392 ]
#   [-0.545098  ]
#   [-0.55294114]
#   ...
#   [-0.57647055]
#   [-0.5215686 ]
#   [-0.4823529 ]]
#
#  [[-0.4588235 ]
#   [-0.5058823 ]
#   [-0.51372546]
#   ...
#   [-0.55294114]
#   [-0.49019605]
#   [-0.45098037]]
#
#  ...
#
#  [[ 0.24705887]
#   [ 0.23921573]
#   [ 0.17647064]
#   ...
#   [-0.16862738]
#   [-0.07450974]
#   [-0.30196077]]
#
#  [[ 0.05098045]
#   [ 0.12941182]
#   [ 0.19215691]
#   ...
#   [ 0.01176476]
#   [ 0.13725495]
#   [ 0.00392163]]
#
#  [[ 0.15294123]
#   [ 0.1686275 ]
#   [ 0.12941182]
#   ...
#   [ 0.20784318]
#   [ 0.27058828]
#   [ 0.13725495]]], shape=(256, 256, 1), dtype=float32)

# %%
plt.imshow(tf.keras.preprocessing.image.random_zoom(x,(0.7,1)))

# %%
plt.imshow(tf.keras.preprocessing.image.random_brightness(
    x, (0.4,0.8)))

# %%
plt.imshow(tf.image.random_brightness(
    x,0.2
))

# %%
plt.imshow(tf.keras.preprocessing.image.random_brightness(x, (0.4,0.8)))

# %%
# Out:
# <tf.Tensor: shape=(256, 256, 1), dtype=float32, numpy=
# array([[[ 37.],
#         [ 32.],
#         [ 31.],
#         ...,
#         [ 46.],
#         [ 48.],
#         [ 51.]],
#
#        [[ 38.],
#         [ 34.],
#         [ 33.],
#         ...,
#         [ 30.],
#         [ 36.],
#         [ 39.]],
#
#        [[ 42.],
#         [ 37.],
#         [ 37.],
#         ...,
#         [ 33.],
#         [ 39.],
#         [ 43.]],
#
#        ...,
#
#        [[109.],
#         [109.],
#         [103.],
#         ...,
#         [ 70.],
#         [ 78.],
#         [ 56.]],
#
#        [[ 90.],
#         [ 98.],
#         [104.],
#         ...,
#         [ 87.],
#         [ 98.],
#         [ 86.]],
#
#        [[100.],
#         [102.],
#         [ 98.],
#         ...,
#         [105.],
#         [111.],
#         [ 98.]]], dtype=float32)>
