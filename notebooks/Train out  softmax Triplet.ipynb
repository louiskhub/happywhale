# %%
import sys
sys.path.append("..")
sys.path.append("../src")
from src import DS_Generator
import tensorflow as tf
import matplotlib.pyplot as plt
from util import TRAIN_SPECIES_DF,TRAIN_DATA_PATH, INDIVIDUMS_SEED
import datetime
import os
from models import return_new_siamese_model

# %%
batch_size = 64
train_ds = DS_Generator.DS_Generator().generate_individual_data(TRAIN_SPECIES_DF,
                                                                        batch_size=batch_size,
                                                                        augment=True,val_split=0.1,
                                                                        seed = INDIVIDUMS_SEED)

# %% [markdown]
# ## Load Best Performing model

# %%
model = return_new_siamese_model()# we load the last weighst

log_dir = "../../models/"+model.name+"/logs"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

checkpoint_path = "../../models/"+model.name+"/saves/" +"/cp-{epoch:04d}.ckpt"

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True)

model.fit(train_ds,
          epochs=100,
          callbacks=[cp_callback,tensorboard_callback])
# Out:
# Epoch 1/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9566
# Epoch 1: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0001.ckpt
# 608/608 [==============================] - 269s 419ms/step - loss: 0.9566
# Epoch 2/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9509
# Epoch 2: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0002.ckpt
# 608/608 [==============================] - 256s 420ms/step - loss: 0.9509
# Epoch 3/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9400
# Epoch 3: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0003.ckpt
# 608/608 [==============================] - 257s 423ms/step - loss: 0.9400
# Epoch 4/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9379
# Epoch 4: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0004.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.9379
# Epoch 5/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9342
# Epoch 5: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0005.ckpt
# 608/608 [==============================] - 259s 425ms/step - loss: 0.9342
# Epoch 6/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9324
# Epoch 6: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0006.ckpt
# 608/608 [==============================] - 259s 425ms/step - loss: 0.9324
# Epoch 7/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9304
# Epoch 7: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0007.ckpt
# 608/608 [==============================] - 251s 413ms/step - loss: 0.9304
# Epoch 8/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9271
# Epoch 8: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0008.ckpt
# 608/608 [==============================] - 255s 420ms/step - loss: 0.9271
# Epoch 9/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9205
# Epoch 9: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0009.ckpt
# 608/608 [==============================] - 258s 425ms/step - loss: 0.9205
# Epoch 10/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9127
# Epoch 10: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0010.ckpt
# 608/608 [==============================] - 257s 423ms/step - loss: 0.9127
# Epoch 11/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9034
# Epoch 11: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0011.ckpt
# 608/608 [==============================] - 254s 417ms/step - loss: 0.9034
# Epoch 12/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9002
# Epoch 12: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0012.ckpt
# 608/608 [==============================] - 251s 412ms/step - loss: 0.9002
# Epoch 13/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9099
# Epoch 13: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0013.ckpt
# 608/608 [==============================] - 251s 413ms/step - loss: 0.9099
# Epoch 14/100
# 608/608 [==============================] - ETA: 0s - loss: 0.9090
# Epoch 14: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0014.ckpt
# 608/608 [==============================] - 248s 407ms/step - loss: 0.9090
# Epoch 15/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8922
# Epoch 15: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0015.ckpt
# 608/608 [==============================] - 248s 408ms/step - loss: 0.8922
# Epoch 16/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8839
# Epoch 16: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0016.ckpt
# 608/608 [==============================] - 260s 428ms/step - loss: 0.8839
# Epoch 17/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8752
# Epoch 17: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0017.ckpt
# 608/608 [==============================] - 259s 425ms/step - loss: 0.8752
# Epoch 18/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8693
# Epoch 18: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0018.ckpt
# 608/608 [==============================] - 258s 424ms/step - loss: 0.8693
# Epoch 19/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8728
# Epoch 19: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0019.ckpt
# 608/608 [==============================] - 258s 425ms/step - loss: 0.8728
# Epoch 20/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8677
# Epoch 20: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0020.ckpt
# 608/608 [==============================] - 249s 409ms/step - loss: 0.8677
# Epoch 21/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8700
# Epoch 21: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0021.ckpt
# 608/608 [==============================] - 259s 425ms/step - loss: 0.8700
# Epoch 22/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8560
# Epoch 22: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0022.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.8560
# Epoch 23/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8446
# Epoch 23: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0023.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.8446
# Epoch 24/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8506
# Epoch 24: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0024.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.8506
# Epoch 25/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8401
# Epoch 25: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0025.ckpt
# 608/608 [==============================] - 260s 428ms/step - loss: 0.8401
# Epoch 26/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8421
# Epoch 26: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0026.ckpt
# 608/608 [==============================] - 256s 421ms/step - loss: 0.8421
# Epoch 27/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8322
# Epoch 27: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0027.ckpt
# 608/608 [==============================] - 256s 422ms/step - loss: 0.8322
# Epoch 28/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8225
# Epoch 28: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0028.ckpt
# 608/608 [==============================] - 272s 448ms/step - loss: 0.8225
# Epoch 29/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8145
# Epoch 29: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0029.ckpt
# 608/608 [==============================] - 269s 442ms/step - loss: 0.8145
# Epoch 30/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8147
# Epoch 30: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0030.ckpt
# 608/608 [==============================] - 264s 435ms/step - loss: 0.8147
# Epoch 31/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8075
# Epoch 31: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0031.ckpt
# 608/608 [==============================] - 263s 433ms/step - loss: 0.8075
# Epoch 32/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8040
# Epoch 32: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0032.ckpt
# 608/608 [==============================] - 259s 427ms/step - loss: 0.8040
# Epoch 33/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8178
# Epoch 33: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0033.ckpt
# 608/608 [==============================] - 257s 422ms/step - loss: 0.8178
# Epoch 34/100
# 608/608 [==============================] - ETA: 0s - loss: 0.8072
# Epoch 34: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0034.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.8072
# Epoch 35/100
# 608/608 [==============================] - ETA: 0s - loss: 0.7908
# Epoch 35: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0035.ckpt
# 608/608 [==============================] - 256s 421ms/step - loss: 0.7908
# Epoch 36/100
# 608/608 [==============================] - ETA: 0s - loss: 0.7855
# Epoch 36: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0036.ckpt
# 608/608 [==============================] - 258s 424ms/step - loss: 0.7855
# Epoch 37/100
# 608/608 [==============================] - ETA: 0s - loss: 0.7761
# Epoch 37: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0037.ckpt
# 608/608 [==============================] - 259s 426ms/step - loss: 0.7761
# Epoch 38/100
# 608/608 [==============================] - ETA: 0s - loss: 0.7743
# Epoch 38: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0038.ckpt
# 608/608 [==============================] - 256s 422ms/step - loss: 0.7743
# Epoch 39/100
# 608/608 [==============================] - ETA: 0s - loss: 0.7755
# Epoch 39: saving model to ../../models/SiameseNetwork_untrained/saves\cp-0039.ckpt
# 608/608 [==============================] - 258s 425ms/step - loss: 0.7755
# Epoch 40/100
# 411/608 [===================>..........] - ETA: 1:21 - loss: 0.7851
